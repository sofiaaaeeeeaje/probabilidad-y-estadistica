# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiaaaeeeeaje/probabilidad-y-estadistica/blob/main/unidad1/pratica6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# ##**Unidad 1**
#
# ### Practica 6. Dataset Autos
#
# ### Profesor: Dr. Jose Gabriel Rodriguez Rivas
#
# ### Alumna: Allisson Sofia Martinez Meraz

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot

# %%
autos = pd.read_csv("autos2.csv", encoding = "ISO-8859-1")
autos.info() #Info tabla
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
print("valor Maximo precio", autos.price.max())
print("valor Minimo precio", autos.price.min())
print("mediana precios:", autos.price.median())
print("media precios:", autos.price.mean())
print("desviacion estandar precios:", autos.price.std())
print("")
print("estadisticos funcion describe:", autos.price.describe())
# Out:
# valor Maximo precio 45400.0
# valor Minimo precio 5118.0
# mediana precios: 10295.0
# media precios: 13207.129353233831
# desviacion estandar precios: 7947.066341939271
#
# estadisticos funcion describe: count      201.000000
# mean     13207.129353
# std       7947.066342
# min       5118.000000
# 25%       7775.000000
# 50%      10295.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
plt.pyplot.hist(autos.price, bins=10)
plt.pyplot.title("histograma precios automoviles")
plt.pyplot.xlabel("precio")
plt.pyplot.ylabel("frecuencia")
# Out:
# Text(0, 0.5, 'frecuencia')

# %%
print("diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil y tipo de vehiculo")
ax = sns.boxplot(x="price", y="body-style", data=autos)
ax.set_ylabel("tipo de vehiculo")
ax.set_xlabel("precio")
# Out:
# diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil y tipo de vehiculo
# Text(0.5, 0, 'precio')

# %%
print("diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil y tipo tracción ruedas")
ax = sns.boxplot(x="price", y="drive-wheels", data=autos)
ax.set_ylabel("traccion de Ruedas")
ax.set_xlabel("precio")
# Out:
# diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil y tipo tracción ruedas
# Text(0.5, 0, 'precio')

# %%
print("diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil y la ubicacion del motor")
ax = sns.boxplot(x="price", y="engine-location", data=autos)
ax.set_ylabel("ubicacion del motor")
ax.set_xlabel("precio")
# Out:
# diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil y la ubicacion del motor
# Text(0.5, 0, 'precio')

# %% [markdown]
# # el precio no se llega a distribuir de manera uniforme, y algunas variables técnicas como la tracción o donde se encuentre el motor tienen q ver mucho en su comportamiento, permitiendo identificar cosas claves de la venta automotriz  representado en el dataset.
