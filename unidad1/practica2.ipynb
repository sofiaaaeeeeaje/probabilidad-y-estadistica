# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiaaaeeeeaje/probabilidad-y-estadistica/blob/main/unidad1/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# ## Unidad 1
#
# ### Practica 2. Maximo, minimo, rango y dispersion de datos.
#
# ### Maestro: Jose Gabriel Rodriguez Rivas
#
# ### Alumna: Allisson Sofia Martinez Meraz

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

fabrica1 = []
for i in range(100):
  random_number = round(random.uniform(50, 100), 2)
  fabrica1.append(random_number)
print(fabrica1)

fabrica2 = []
for i in range(100):
  random_number = round(random.uniform(50, 100), 2)
  fabrica2.append(random_number)
print(fabrica2)
# Out:
# [58.15, 79.56, 94.38, 84.14, 92.14, 58.88, 75.09, 58.28, 79.24, 88.94, 80.57, 96.03, 86.99, 86.71, 53.4, 88.65, 64.0, 87.9, 52.84, 93.91, 68.11, 52.85, 68.74, 73.89, 54.88, 90.5, 66.37, 77.97, 52.19, 72.31, 70.27, 66.84, 76.94, 84.64, 82.08, 75.53, 77.3, 63.32, 63.83, 65.81, 87.89, 98.8, 57.18, 95.49, 98.58, 55.88, 81.83, 90.94, 84.01, 85.06, 67.49, 86.53, 55.8, 84.22, 56.9, 90.47, 77.87, 92.02, 70.44, 57.73, 50.55, 51.1, 52.84, 88.7, 61.22, 68.58, 71.14, 75.37, 50.52, 58.6, 78.44, 83.96, 89.03, 96.56, 87.51, 73.65, 53.25, 97.49, 51.96, 62.58, 66.99, 60.71, 88.87, 75.78, 58.09, 74.39, 61.29, 71.76, 50.07, 88.37, 65.97, 91.56, 75.58, 97.73, 99.58, 51.62, 99.43, 63.11, 81.09, 98.36]
# [72.36, 66.45, 71.67, 84.87, 94.15, 64.22, 92.81, 55.2, 62.98, 73.94, 66.55, 58.43, 86.55, 67.47, 90.58, 65.74, 91.66, 78.15, 85.58, 92.32, 53.07, 68.62, 78.76, 78.79, 87.54, 91.06, 53.42, 99.02, 76.4, 88.53, 51.49, 67.55, 65.76, 90.13, 86.04, 80.8, 67.16, 64.33, 67.4, 62.95, 70.65, 64.95, 66.95, 86.92, 58.14, 94.45, 50.02, 72.28, 60.18, 70.69, 78.83, 80.86, 86.37, 59.54, 84.61, 71.97, 92.35, 91.95, 90.76, 61.93, 72.69, 80.47, 98.76, 52.13, 60.82, 74.98, 58.44, 76.61, 61.01, 90.15, 72.15, 57.44, 79.29, 78.71, 92.45, 97.73, 73.69, 54.05, 97.44, 81.33, 66.02, 92.29, 95.73, 74.83, 82.7, 76.57, 93.91, 55.08, 73.45, 95.42, 60.01, 79.05, 56.42, 92.11, 78.79, 54.68, 74.32, 94.35, 99.46, 84.68]

# %%
max1= max(fabrica1)
min1= min(fabrica1)
media1= mean(fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)
rango1= max1-min1
desviacion1= stdev(fabrica1)

max2= max(fabrica2)
min2= min(fabrica2)
media2= mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)
rango2= max2-min2
desviacion2= stdev(fabrica2)

print("Estadistica Descriptiva de la fabrica 1 \n", "Media =", media1,
      "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo=", max1,
      "\n Minimo =", min1, "\n Rango =", rango1, "\n Desviacion:", desviacion1)
print("")
print("Estadistica Descriptiva de la fabrica 2 \n", "Media =", media2,
      "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo=", max2,
      "\n Minimo =", min2, "\n Rango =", rango2, "\n Desviacion:", desviacion2)
# Out:
# Estadistica Descriptiva de la fabrica 1
#  Media = 74.627
#  Mediana = 75.45
#  Moda = 52.84
#  Maximo= 99.58
#  Minimo = 50.07
#  Rango = 49.51
#  Desviacion: 14.937807466934093
#
# Estadistica Descriptiva de la fabrica 2
#  Media = 75.8511
#  Mediana = 75.69
#  Moda = 78.79
#  Maximo= 99.46
#  Minimo = 50.02
#  Rango = 49.43999999999999
#  Desviacion: 13.72552307295655

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar={desviacion1:.2f}')
plt.axvline(media1 + desviacion1, color='black', linestyle='dashed', linewidth=2)


plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media1 - desviacion2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar={desviacion2:.2f}')
plt.axvline(media1 + desviacion2, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
from matplotlib.axes import Axes
import seaborn as sns

sns.histplot( x=fabrica1, kde= True, kde_kws={'bw_adjust': 0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot( x=fabrica2, kde= True, kde_kws={'bw_adjust': 0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>
