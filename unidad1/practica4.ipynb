# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiaaaeeeeaje/probabilidad-y-estadistica/blob/main/unidad1/practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# ## **unidad** **1**
#
# ### Practica 4. Diagramas de Cajas y bigotes
#
# ### Profesor: Dr. Jose Gabriel Rodriguez Rivas
#
# ### Alumna: Allisson Sofia Martinez Meraz

# %%
import random
import matplotlib.pyplot as ptl
from statistics import *

fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [58.84, 92.28, 70.4, 87.2, 89.58, 71.28, 52.4, 56.66, 69.02, 81.24, 55.64, 60.38, 56.24, 53.54, 53.04, 93.83, 86.92, 72.88, 59.65, 89.79, 53.82, 99.5, 94.99, 66.36, 81.89, 86.67, 92.85, 79.88, 72.59, 65.79, 63.35, 86.37, 90.41, 63.11, 50.65, 76.97, 59.69, 54.59, 93.12, 71.65, 53.52, 62.3, 96.48, 95.39, 84.28, 83.53, 54.64, 93.86, 70.62, 75.42, 84.26, 73.73, 53.7, 71.73, 79.34, 76.6, 87.16, 87.19, 96.97, 55.46, 57.72, 50.73, 87.3, 57.37, 85.5, 83.3, 51.23, 52.83, 92.54, 55.0, 65.88, 71.57, 64.8, 55.82, 70.3, 87.98, 85.07, 63.15, 90.57, 50.16, 69.2, 67.23, 59.76, 79.18, 56.41, 54.14, 94.47, 86.9, 79.73, 53.85, 88.96, 63.12, 94.94, 64.87, 65.87, 91.83, 90.05, 57.11, 54.23, 91.14]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [46.54, 69.28, 78.45, 42.97, 91.38, 47.27, 63.63, 86.04, 57.41, 76.23, 52.49, 86.03, 78.18, 87.48, 63.84, 61.31, 43.53, 51.38, 44.7, 60.69, 51.03, 56.11, 51.14, 71.05, 78.43, 89.7, 56.94, 86.53, 73.34, 80.71, 79.25, 91.87, 69.66, 62.44, 79.34, 81.87, 92.31, 64.59, 77.81, 91.76, 55.65, 80.54, 80.51, 68.07, 64.96, 59.97, 52.67, 61.25, 68.84, 77.45, 44.05, 86.01, 67.87, 83.04, 56.58, 85.67, 46.53, 85.62, 72.7, 57.71, 92.85, 76.5, 61.65, 55.85, 72.44, 45.25, 66.95, 62.2, 69.13, 52.73, 40.14, 49.53, 55.22, 61.46, 69.87, 51.0, 50.5, 68.74, 71.19, 68.96, 67.1, 69.25, 59.16, 45.22, 77.95, 40.64, 57.46, 81.41, 82.35, 58.4, 40.92, 91.86, 84.93, 43.24, 86.57, 74.25, 71.86, 55.64, 89.69, 86.41]

# %%
ptl.boxplot(fabrica1)
ptl.ylabel('producción en mts.')
ptl.title('producción de la fabrica 1')
ptl.show()

# %%
fig, (ax1, ax2) = ptl.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('producción de la fabrica 1')
bplot2 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('producción de la fabrica 2')
ptl.show()

# %%
fig,(ax1,ax2) = ptl.subplots(nrows=1,ncols=2,figsize=(9,4))
bplot1 = ax1.boxplot(fabrica1,vert=True,patch_artist=True)
ax1.set_title('producción de la fabrica 1')
bplot2 = ax2.boxplot(fabrica2,vert=True,patch_artist=True)
ax2.set_title('producción de la fabrica 2')
ptl.show()

# %%
fig,(ax1,ax2) = ptl.subplots(nrows=1,ncols=2,figsize=(9,5))
bplot1 = ax1.boxplot(fabrica1,vert=True,patch_artist=True)
ax1.set_title('producción de la fabrica 1')
ax1.set_ylim(30, 160)
bplot2 = ax2.boxplot(fabrica2,vert=True,patch_artist=True)
ax2.set_title('producción de la fabrica 2')
ax2.set_ylim(30, 160)
ptl.show()
