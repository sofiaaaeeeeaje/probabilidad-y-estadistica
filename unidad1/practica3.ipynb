# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiaaaeeeeaje/probabilidad-y-estadistica/blob/main/unidad1/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# ## Unidad 1
#
# ### Practica 3. Tablas de frecuencias
#
# ### Maestro: Dr. Jose Gabriel Rodriguez Rivas
#
# ### Alumna: Allisson Sofia Martinez Meraz

# %%
import random
import pandas as pd

edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [57, 25, 47, 19, 39, 47, 54, 27, 50, 42, 30, 52, 38, 40, 42, 25, 64, 53, 37, 28, 50, 62, 30, 46, 69, 27, 53, 61, 43, 27, 53, 31, 47, 51, 55, 36, 18, 46, 63, 23, 54, 61, 45, 51, 27, 54, 27, 39, 43, 24, 27, 66, 19, 63, 19, 42, 59, 23, 70, 59, 67, 34, 39, 47, 66, 33, 36, 41, 51, 30, 47, 28, 42, 70, 46, 59, 53, 45, 26, 65, 23, 54, 66, 37, 27, 64, 63, 66, 48, 29, 26, 26, 50, 56, 22, 40, 63, 52, 18, 30]

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    57
# 1    25
# 2    47
# 3    19
# 4    39

# %%
tabla_frec = df['Edad'].value_counts().reset_index()
tabla_frec.columns = ['Edad', 'Frecuencia']
tabla_frec = tabla_frec.sort_values(by='Edad')

print("Tabla de distribucion de frecuencias:")
tabla_frec
# Out:
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 20    18           2
# 10    19           3
# 43    22           1
# 14    23           3
# 35    24           1
# 18    25           2
# 12    26           3
# 0     27           7
# 25    28           2
# 41    29           1
# 3     30           4
# 33    31           1
# 37    33           1
# 36    34           1
# 21    36           2
# 24    37           2
# 28    38           1
# 11    39           3
# 27    40           2
# 38    41           1
# 4     42           4
# 22    43           2
# 17    45           2
# 15    46           3
# 1     47           5
# 40    48           1
# 9     50           3
# 8     51           3
# 19    52           2
# 7     53           4
# 2     54           4
# 32    55           1
# 42    56           1
# 29    57           1
# 13    59           3
# 23    61           2
# 30    62           1
# 6     63           4
# 26    64           2
# 39    65           1
# 5     66           4
# 34    67           1
# 31    69           1
# 16    70           2

# %%
tabla_frec['Frec Relativa'] = tabla_frec['Frecuencia'] / 100
tabla_frec
# Out:
#     Edad  Frecuencia  Frec Relativa
# 20    18           2           0.02
# 10    19           3           0.03
# 43    22           1           0.01
# 14    23           3           0.03
# 35    24           1           0.01
# 18    25           2           0.02
# 12    26           3           0.03
# 0     27           7           0.07
# 25    28           2           0.02
# 41    29           1           0.01
# 3     30           4           0.04
# 33    31           1           0.01
# 37    33           1           0.01
# 36    34           1           0.01
# 21    36           2           0.02
# 24    37           2           0.02
# 28    38           1           0.01
# 11    39           3           0.03
# 27    40           2           0.02
# 38    41           1           0.01
# 4     42           4           0.04
# 22    43           2           0.02
# 17    45           2           0.02
# 15    46           3           0.03
# 1     47           5           0.05
# 40    48           1           0.01
# 9     50           3           0.03
# 8     51           3           0.03
# 19    52           2           0.02
# 7     53           4           0.04
# 2     54           4           0.04
# 32    55           1           0.01
# 42    56           1           0.01
# 29    57           1           0.01
# 13    59           3           0.03
# 23    61           2           0.02
# 30    62           1           0.01
# 6     63           4           0.04
# 26    64           2           0.02
# 39    65           1           0.01
# 5     66           4           0.04
# 34    67           1           0.01
# 31    69           1           0.01
# 16    70           2           0.02

# %%
tabla_frec['Frec Porcentual'] = tabla_frec['Frecuencia'] / 100 * 100
tabla_frec
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 20    18           2           0.02              2.0
# 10    19           3           0.03              3.0
# 43    22           1           0.01              1.0
# 14    23           3           0.03              3.0
# 35    24           1           0.01              1.0
# 18    25           2           0.02              2.0
# 12    26           3           0.03              3.0
# 0     27           7           0.07              7.0
# 25    28           2           0.02              2.0
# 41    29           1           0.01              1.0
# 3     30           4           0.04              4.0
# 33    31           1           0.01              1.0
# 37    33           1           0.01              1.0
# 36    34           1           0.01              1.0
# 21    36           2           0.02              2.0
# 24    37           2           0.02              2.0
# 28    38           1           0.01              1.0
# 11    39           3           0.03              3.0
# 27    40           2           0.02              2.0
# 38    41           1           0.01              1.0
# 4     42           4           0.04              4.0
# 22    43           2           0.02              2.0
# 17    45           2           0.02              2.0
# 15    46           3           0.03              3.0
# 1     47           5           0.05              5.0
# 40    48           1           0.01              1.0
# 9     50           3           0.03              3.0
# 8     51           3           0.03              3.0
# 19    52           2           0.02              2.0
# 7     53           4           0.04              4.0
# 2     54           4           0.04              4.0
# 32    55           1           0.01              1.0
# 42    56           1           0.01              1.0
# 29    57           1           0.01              1.0
# 13    59           3           0.03              3.0
# 23    61           2           0.02              2.0
# 30    62           1           0.01              1.0
# 6     63           4           0.04              4.0
# 26    64           2           0.02              2.0
# 39    65           1           0.01              1.0
# 5     66           4           0.04              4.0
# 34    67           1           0.01              1.0
# 31    69           1           0.01              1.0
# 16    70           2           0.02              2.0

# %%
tabla_frec['Frec Acumulada'] = tabla_frec['Frecuencia'].cumsum()
tabla_frec
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 20    18           2           0.02              2.0               2
# 10    19           3           0.03              3.0               5
# 43    22           1           0.01              1.0               6
# 14    23           3           0.03              3.0               9
# 35    24           1           0.01              1.0              10
# 18    25           2           0.02              2.0              12
# 12    26           3           0.03              3.0              15
# 0     27           7           0.07              7.0              22
# 25    28           2           0.02              2.0              24
# 41    29           1           0.01              1.0              25
# 3     30           4           0.04              4.0              29
# 33    31           1           0.01              1.0              30
# 37    33           1           0.01              1.0              31
# 36    34           1           0.01              1.0              32
# 21    36           2           0.02              2.0              34
# 24    37           2           0.02              2.0              36
# 28    38           1           0.01              1.0              37
# 11    39           3           0.03              3.0              40
# 27    40           2           0.02              2.0              42
# 38    41           1           0.01              1.0              43
# 4     42           4           0.04              4.0              47
# 22    43           2           0.02              2.0              49
# 17    45           2           0.02              2.0              51
# 15    46           3           0.03              3.0              54
# 1     47           5           0.05              5.0              59
# 40    48           1           0.01              1.0              60
# 9     50           3           0.03              3.0              63
# 8     51           3           0.03              3.0              66
# 19    52           2           0.02              2.0              68
# 7     53           4           0.04              4.0              72
# 2     54           4           0.04              4.0              76
# 32    55           1           0.01              1.0              77
# 42    56           1           0.01              1.0              78
# 29    57           1           0.01              1.0              79
# 13    59           3           0.03              3.0              82
# 23    61           2           0.02              2.0              84
# 30    62           1           0.01              1.0              85
# 6     63           4           0.04              4.0              89
# 26    64           2           0.02              2.0              91
# 39    65           1           0.01              1.0              92
# 5     66           4           0.04              4.0              96
# 34    67           1           0.01              1.0              97
# 31    69           1           0.01              1.0              98
# 16    70           2           0.02              2.0             100

# %%
import math
print(edades)
df = pd.DataFrame(edades, columns=['Edad'])
df

n =len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n, "\nNumero de intervalos =", K)

tabla_frecuencia = pd.cut(df['Edad'], bins=K).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
# [57, 25, 47, 19, 39, 47, 54, 27, 50, 42, 30, 52, 38, 40, 42, 25, 64, 53, 37, 28, 50, 62, 30, 46, 69, 27, 53, 61, 43, 27, 53, 31, 47, 51, 55, 36, 18, 46, 63, 23, 54, 61, 45, 51, 27, 54, 27, 39, 43, 24, 27, 66, 19, 63, 19, 42, 59, 23, 70, 59, 67, 34, 39, 47, 66, 33, 36, 41, 51, 30, 47, 28, 42, 70, 46, 59, 53, 45, 26, 65, 23, 54, 66, 37, 27, 64, 63, 66, 48, 29, 26, 26, 50, 56, 22, 40, 63, 52, 18, 30]
# Valor de n =  100
# Numero de intervalos = 7
#               Clase  Frec
# 0  (25.429, 32.857]    18
# 1  (47.714, 55.143]    18
# 2  (40.286, 47.714]    17
# 3    (62.571, 70.0]    15
# 4  (17.948, 25.429]    12
# 5  (32.857, 40.286]    12
# 6  (55.143, 62.571]     8

# %%
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 4  (17.948, 25.429]    12
# 0  (25.429, 32.857]    18
# 5  (32.857, 40.286]    12
# 2  (40.286, 47.714]    17
# 1  (47.714, 55.143]    18
# 6  (55.143, 62.571]     8
# 3    (62.571, 70.0]    15

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Drec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Drec Rel Ac  \
# 4  (17.948, 25.429]    12      0.12       12.0       12         0.12
# 0  (25.429, 32.857]    18      0.18       18.0       30         0.30
# 5  (32.857, 40.286]    12      0.12       12.0       42         0.42
# 2  (40.286, 47.714]    17      0.17       17.0       59         0.59
# 1  (47.714, 55.143]    18      0.18       18.0       77         0.77
# 6  (55.143, 62.571]     8      0.08        8.0       85         0.85
# 3    (62.571, 70.0]    15      0.15       15.0      100         1.00
#
#    Frec Porc Ac
# 4          12.0
# 0          30.0
# 5          42.0
# 2          59.0
# 1          77.0
# 6          85.0
# 3         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades, alpha = 0.5)
plt.title('histograma de edades')
# Out:
# Text(0.5, 1.0, 'histograma de edades')

# %%
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('histograma de edades basado en la regla de Sturges')
plt.xlabel('edad')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')
